# %% [markdown]
# <a href="https://colab.research.google.com/github/akeel2000/Deep-Learning-Labs/blob/main/Lab%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #task 1

# %%
import numpy as np

# %%
np.random.exponential(size=(4,4))
# Out:
# array([[3.568111  , 1.08757301, 0.82943821, 0.80929532],
#        [0.22726659, 0.15841084, 1.60949586, 0.17759093],
#        [0.31129725, 0.22204099, 1.62245279, 0.10110997],
#        [1.32183196, 1.25948748, 0.87384107, 0.26818463]])

# %%
np.random.exponential(scale=1.0, size=(4, 4))
# Out:
# array([[0.10559718, 0.33034084, 2.53015684, 4.40598402],
#        [1.66395543, 0.83983634, 0.39792431, 0.01444926],
#        [0.79215861, 0.63268833, 3.32851267, 0.27370547],
#        [0.20420616, 0.18854095, 0.03981024, 0.05381804]])

# %%
exp_data = np.random.exponential(scale=1.0, size=100000)
uniform_data = np.random.rand(100000)
normal_data = np.random.randn(100000)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(uniform_data, density=True, bins=100, histtype="step", color="blue", label="Uniform")
plt.hist(normal_data, density=True, bins=100, histtype="step", color="green", label="Normal")
plt.hist(exp_data, density=True, bins=100, histtype="step", color="red", label="Exponential")
# Out:
# (array([9.62808863e-01, 8.29901805e-01, 7.68889187e-01, 6.88717120e-01,
#         6.18403799e-01, 5.54693978e-01, 5.02331015e-01, 4.44852665e-01,
#         3.97512083e-01, 3.63843535e-01, 3.19572184e-01, 2.81067270e-01,
#         2.60884743e-01, 2.34656758e-01, 2.07777724e-01, 1.86944147e-01,
#         1.74853232e-01, 1.49369304e-01, 1.41091677e-01, 1.26768593e-01,
#         1.10027327e-01, 1.01005644e-01, 8.91007429e-02, 8.06371024e-02,
#         7.17084267e-02, 6.79881451e-02, 6.31517791e-02, 5.15258993e-02,
#         4.42713503e-02, 3.94349843e-02, 3.78538647e-02, 3.24594564e-02,
#         2.91112030e-02, 2.79021115e-02, 2.70650482e-02, 2.29727385e-02,
#         1.98104992e-02, 1.78573514e-02, 1.58111965e-02, 1.37650417e-02,
#         1.33930135e-02, 1.05097954e-02, 9.02168273e-03, 8.92867570e-03,
#         7.90559827e-03, 7.16154196e-03, 5.67342935e-03, 6.41748566e-03,
#         4.83636600e-03, 5.30140119e-03, 5.11538712e-03, 4.09230969e-03,
#         3.53426746e-03, 2.79021115e-03, 2.69720412e-03, 2.41818300e-03,
#         2.60419708e-03, 1.58111965e-03, 1.67412669e-03, 1.76713373e-03,
#         1.58111965e-03, 1.67412669e-03, 1.48811262e-03, 1.02307742e-03,
#         1.11608446e-03, 7.44056308e-04, 6.51049269e-04, 8.37063346e-04,
#         4.65035192e-04, 1.11608446e-03, 2.79021115e-04, 4.65035192e-04,
#         3.72028154e-04, 3.72028154e-04, 3.72028154e-04, 2.79021115e-04,
#         9.30070385e-05, 1.86014077e-04, 4.65035192e-04, 1.86014077e-04,
#         9.30070385e-05, 9.30070385e-05, 0.00000000e+00, 0.00000000e+00,
#         9.30070385e-05, 0.00000000e+00, 1.86014077e-04, 9.30070385e-05,
#         1.86014077e-04, 9.30070385e-05, 9.30070385e-05, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00,
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
import matplotlib

# %%
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)

Z = X**2 + Y**2

figure = plt.figure(1, figsize=(12, 4))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z, rstride=1, cstride=1,
                                 cmap=matplotlib.cm.coolwarm, linewidth=0.1)

plt.show()

# %%
x = np.linspace(-5, 5)
y = np.linspace(-5, 5)
X, Y = np.meshgrid(x, y)

Z = X**2 + Y**2

figure = plt.figure(1, figsize=(12, 4))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z, rstride=1, cstride=1,
                                 cmap=matplotlib.cm.coolwarm, linewidth=0.1)

plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
# Seaborn for plotting and styling
import seaborn as sns

# %%
# !wget -q https://elitedatascience.com/wp-content/uploads/2022/07/Pokemon.csv
# Read dataset
df = pd.read_csv('Pokemon.csv', index_col=0, encoding='latin')

# %%
df.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %%
stats_df = df.drop(['Total', 'Stage', 'Legendary'], axis=1)

# %%
corr = stats_df.drop(['Name', 'Type 1', 'Type 2'], axis=1).corr()

# %%
corr
# Out:
#                HP    Attack   Defense   Sp. Atk   Sp. Def     Speed
# HP       1.000000  0.306768  0.119782  0.236649  0.490978 -0.040939
# Attack   0.306768  1.000000  0.491965  0.146312  0.369069  0.194701
# Defense  0.119782  0.491965  1.000000  0.187569  0.139912 -0.053252
# Sp. Atk  0.236649  0.146312  0.187569  1.000000  0.522907  0.411516
# Sp. Def  0.490978  0.369069  0.139912  0.522907  1.000000  0.392656
# Speed   -0.040939  0.194701 -0.053252  0.411516  0.392656  1.000000

# %%
plt.figure(figsize=(9,8))
sns.heatmap(corr)
# Out:
# <Axes: >

# %% [markdown]
# # Task 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load CSV (make sure you've uploaded Au_nanoParticle_dataset.csv in Colab)
df = pd.read_csv("/content/sample_data/Au_nanoparticle_dataset.csv")

# View first few rows to confirm
df.head()
# Out:
#    ID    T       tau  time  N_total  N_bulk  N_surface        Volume    R_min  \
# 0   1  273  0.000025     1     1599    1014        585  2.710000e-26  15.5898
# 1   2  273  0.000025     2     1642    1034        608  2.780000e-26  15.3996
# 2   3  273  0.000025     3     4637    3365       1272  7.850000e-26  21.9199
# 3   4  273  0.000025     4     7189    5292       1897  1.220000e-25  23.2542
# 4   5  273  0.000025     5    11004    8508       2496  1.860000e-25  27.1200
#
#      R_max  ...  q6q6_S14  q6q6_S15  q6q6_S16  q6q6_S17  q6q6_S18  q6q6_S19  \
# 0  19.4516  ...         0         0         0         0         0         0
# 1  24.1755  ...         0         0         0         0         0         0
# 2  31.0305  ...         0         0         0         0         0         0
# 3  37.8795  ...         0         0         0         0         0         0
# 4  39.7614  ...         0         0         0         0         0         0
#
#    q6q6_S20  q6q6_S20+     Total_E  Formation_E
# 0         0          0  -5908.6345     343.4555
# 1         0          0  -6035.4034     384.8166
# 2         0          0 -17330.1660     800.5040
# 3         0          0 -26937.2010    1171.7890
# 4         0          0 -41427.9010    1597.7390
#
# [5 rows x 185 columns]

# %% [markdown]
# Step 1 – Create new dataframe with only 4 required columns

# %%
# Keep only the required columns
new_df = df[['N_total', 'N_bulk', 'N_surface', 'R_avg']]

# %% [markdown]
# Step 2 – Display first 20 samples

# %%
new_df.head(20)
# Out:
#     N_total  N_bulk  N_surface    R_avg
# 0      1599    1014        585  17.3706
# 1      1642    1034        608  17.6061
# 2      4637    3365       1272  25.3692
# 3      7189    5292       1897  29.7011
# 4     11004    8508       2496  34.2831
# 5     13375   10768       2607  36.6334
# 6     13795   11155       2640  37.0108
# 7     13947   11304       2643  37.1672
# 8     14020   11357       2663  37.2103
# 9     14056   11389       2667  37.2467
# 10     1534     966        568  17.1107
# 11     1559     974        585  17.2101
# 12     4356    3099       1257  24.8253
# 13     6550    4675       1875  29.0376
# 14    10175    7748       2427  33.4399
# 15    12393    9842       2551  35.6950
# 16    13207   10590       2617  36.4657
# 17    13543   10937       2606  36.7871
# 18    13713   11079       2634  36.9333
# 19    13791   11151       2640  37.0104

# %% [markdown]
# Step 3 – Calculate mean, standard deviation & quartiles

# %%
# Mean
mean_values = new_df.mean()

# Standard Deviation
std_values = new_df.std()

# Quartiles
quartiles = new_df.quantile([0.25, 0.5, 0.75])

print("Mean values:\n", mean_values)
print("\nStandard Deviation:\n", std_values)
print("\nQuartile values:\n", quartiles)
# Out:
# Mean values:
#  N_total      3476.786500
# N_bulk       2521.550250
# N_surface     955.236250
# R_avg          20.654363
# dtype: float64
#
# Standard Deviation:
#  N_total      3679.286769
# N_bulk       2976.232459
# N_surface     721.870220
# R_avg           7.610716
# dtype: float64
#
# Quartile values:
#        N_total   N_bulk  N_surface      R_avg
# 0.25   1061.0   618.75     437.00  15.160725
# 0.50   1867.0  1199.00     666.00  18.629250
# 0.75   4503.0  3183.00    1301.75  25.525125

# %% [markdown]
# Step 4 – Plot histogram for each feature in a 1x4 layout

# %%
plt.figure(figsize=(16, 4))

for i, col in enumerate(new_df.columns, 1):
    plt.subplot(1, 4, i)
    plt.hist(new_df[col], bins=20, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# Step 5 – Seaborn Pairplot (scatter plots & histograms)

# %%
sns.pairplot(new_df, diag_kind='hist')
plt.show()

# %% [markdown]
# Step 6 – Customized PairGrid with KDE & Hist

# %%
g = sns.PairGrid(new_df)

# Upper half – let's keep scatterplots
g.map_upper(sns.scatterplot, color='green', s=20)

# Diagonal – histogram + KDE overlay
def hist_kde(x, color, label, **kwargs):
    sns.histplot(x, kde=True, color=color, edgecolor='black', **kwargs)

g.map_diag(hist_kde)

# Lower half – bivariate KDE
g.map_lower(sns.kdeplot, fill=True, cmap='Blues')

plt.show()
